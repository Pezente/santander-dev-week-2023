# %% [markdown]
# # 🚨 A API Está Fora do Ar? Sem Problemas!
#
# A API utilizada neste projeto (`sdw-2023-prd.up.railway.app`) era um ambiente público de demonstração e foi descontinuada. **Isso não impede você de concluir este desafio** 🚀
#
# Como reforçado nas aulas, o objetivo principal aqui é compreender o fluxo **ETL (Extração, Transformação e Carregamento)**. Se a API não estiver respondendo, você pode substituir a etapa de **Extract** e ajustar a **Load** sem prejuízo ao aprendizado.

# %% [markdown]
# ## Ajustando a Etapa de Extract
#
# ### 🟢 Opção 1: Mais Simples (Dados Direto no Código)
#
# Ideal se você quiser focar exclusivamente na lógica e no uso de IA, sem depender de arquivos externos.
#
# ```python
# # Simula a extração de dados (substituindo o GET da API)
# users = [
#     {'id': 1, 'name': 'Naruto', 'news': []},
#     {'id': 2, 'name': 'Hinata', 'news': []}
# ]
# ```
#
# ### 🟡 Opção 2: Mais Completa (Leitura de Arquivo)
#
# Você pode adaptar o arquivo `SDW2023.csv`, incluindo a coluna `name`, e usá-lo como fonte de dados.
#
# ```python
# import pandas as pd
#
# # Lê o CSV e converte para uma lista de dicionários
# users = pd.read_csv('SDW2023.csv').to_dict(orient='records')
#
# # Garante a estrutura esperada para a etapa de Transformação
# for user in users:
#     user['news'] = []
# ```

# %% [markdown]
# ## E a Etapa de Load?
#
# Como a API está indisponível, a chamada `PUT` não funcionará. Para finalizar o Lab, basta salvar o resultado localmente (em um arquivo CSV, JSON ou mesmo exibindo no console).
#
# O mais importante é demonstrar que você entende como os dados percorrem todas as etapas do **ETL**, independentemente da ferramenta ou fonte utilizada 😉

# %% [markdown]
# # Santander Dev Week 2023 (ETL com Python)

# %% [markdown]
# **Contexto:** Você é um cientista de dados no Santander e recebeu a tarefa de envolver seus clientes de maneira mais personalizada. Seu objetivo é usar o poder da IA Generativa para criar mensagens de marketing personalizadas que serão entregues a cada cliente.
#
# **Condições do Problema:**
#
# 1. Você recebeu uma planilha simples, em formato CSV ('SDW2023.csv'), com uma lista de IDs de usuário do banco:
#   ```
#   UserID
#   1
#   2
#   3
#   4
#   5
#   ```
# 2. Seu trabalho é consumir o endpoint `GET https://sdw-2023-prd.up.railway.app/users/{id}` (API da Santander Dev Week 2023) para obter os dados de cada cliente.
# 3. Depois de obter os dados dos clientes, você vai usar a API do ChatGPT (OpenAI) para gerar uma mensagem de marketing personalizada para cada cliente. Essa mensagem deve enfatizar a importância dos investimentos.
# 4. Uma vez que a mensagem para cada cliente esteja pronta, você vai enviar essas informações de volta para a API, atualizando a lista de "news" de cada usuário usando o endpoint `PUT https://sdw-2023-prd.up.railway.app/users/{id}`.

# %% [markdown]
# ## **E**xtract
#
# Extraia a lista de IDs de usuário a partir do arquivo CSV. Para cada ID, faça uma requisição GET para obter os dados do usuário correspondente.

# %%
import pandas as pd

# Lê o CSV e converte para uma lista de dicionários
users = pd.read_csv('SDW2023.csv').to_dict(orient='records')

# Garante a estrutura esperada para a etapa de Transformação
for user in users:
    user['news'] = []

print(users)
# Out:
# [{'id': 4, 'name': 'Pyterson', 'news': []}, {'id': 5, 'name': 'Pip', 'news': []}, {'id': 6, 'name': 'Pep', 'news': []}]

# %% [markdown]
# ## **T**ransform
#
# Utilize a API do OpenAI GPT-4 para gerar uma mensagem de marketing personalizada para cada usuário.
#
# Nesse passo, salvei em um arquivo separado as mensagens geradas para cada usuário, pois a API da OpenAI não estava funcionando

# %%
with open('SDW2023_messages.txt', 'r') as f:
    messages = f.read()

print(messages)
# Out:
# [{"name": "Pyterson",
# "message": "Pyterson, investir hoje é garantir um futuro mais seguro e tranquilo!"},
# {"name": "Pip",
# "message": "Pip, comece a investir já e conquiste seus objetivos financeiros!"},
# {"name": "Pep",
# "message": "Pep, investir é o caminho para crescer seu patrimônio com segurança."}]

# %%
import json
parsed_messages = json.loads(messages)

for i, user in enumerate(users):
  # Get the pre-generated message for the current user
  # Access the 'message' field from the dictionary in the parsed_messages list
  news = parsed_messages[i]['message']

  print(f"{user['name']}: {news}")
  user['news'].append({
      "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
      "description": news
  })
# Out:
# Pyterson: Pyterson, investir hoje é garantir um futuro mais seguro e tranquilo!
# Pip: Pip, comece a investir já e conquiste seus objetivos financeiros!
# Pep: Pep, investir é o caminho para crescer seu patrimônio com segurança.

# %% [markdown]
# ## **L**oad
#
# Atualize a lista de "news" de cada usuário na API com a nova mensagem gerada.

# %%
output_filename = 'updated_users.json'

# Save the updated users list to a JSON file
with open(output_filename, 'w', encoding='utf-8') as f:
    json.dump(users, f, ensure_ascii=False, indent=4)

print(f"Updated user data saved to '{output_filename}'\n")

# Display the content of the saved file
with open(output_filename, 'r', encoding='utf-8') as f:
    saved_content = f.read()
print("Content of 'updated_users.json':\n")
print(saved_content)
# Out:
# Updated user data saved to 'updated_users.json'
#
# Content of 'updated_users.json':
#
# [
#     {
#         "id": 4,
#         "name": "Pyterson",
#         "news": [
#             {
#                 "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#                 "description": "Pyterson, investir hoje é garantir um futuro mais seguro e tranquilo!"
#             }
#         ]
#     },
#     {
#         "id": 5,
#         "name": "Pip",
#         "news": [
#             {
#                 "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#                 "description": "Pip, comece a investir já e conquiste seus objetivos financeiros!"
#             }
#         ]
#     },
#     {
#         "id": 6,
#         "name": "Pep",
#         "news": [
#             {
#                 "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
#                 "description": "Pep, investir é o caminho para crescer seu patrimônio com segurança."
#             }
#         ]
#     }
# ]
